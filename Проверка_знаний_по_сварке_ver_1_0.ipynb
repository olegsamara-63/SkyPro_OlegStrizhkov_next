# %% [markdown]
# <a href="https://colab.research.google.com/github/olegsamara-63/SkyPro_OlegStrizkov_next/blob/main/%D0%9F%D1%80%D0%BE%D0%B2%D0%B5%D1%80%D0%BA%D0%B0_%D0%B7%D0%BD%D0%B0%D0%BD%D0%B8%D0%B9_%D0%BF%D0%BE_%D1%81%D0%B2%D0%B0%D1%80%D0%BA%D0%B5_ver_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
import random
from typing import Dict, Tuple, List

print(f"Вас приветствует программа проверки знаний специалиста сварочного производства. \nГотовы пройти проверку своих знаний?"
      f"\n Если готовы, наберите слово -\nДа, \nЕсли нет, наберите слово -\nНет. \nДля ознакомления с материалами программы проверки"
      f"\nнаберите слово -\nЧитать.")

my_dict = {'I-первый класс': 'Диаметр трубопровода 1000 - 1200 мм включительно',
           'II-второй класс': 'Диаметр трубопровода 500 - 1000 мм включительно',
           'III-третий класс': 'Диаметр трубопровода 300 - 500 мм включительно',
           'IV-четвёртый класс': 'Диаметр трубопровода 300 мм и менее'}

answer_user = input("Ваш ответ ... ")

if answer_user.lower().strip(" ") == 'да':
    print("Введите Ваше Имя...")
    user_name = input(str())
    count_user = 0
    print(f"{user_name}, начинайте отвечать на вопросы, чтобы остановить проверку, наберите слово: стоп")
    random_key = random.choice(list(my_dict.keys()))  # выбираем случайный ключ из списка ключей словаря

    keys_list = list(my_dict.keys())  # создаем список ключей словаря
    print(f"Условие: Нефтепровод -  {random_key},\nВОПРОС: Напишите любой диаметр соответсвующий такому классу нефтепровода в миллиметрах: "
          f"\nдиаметры могут быть от 10 и до 1200 мм включительно")  # выводим первый ключ из списка, который соответствует первому элементу словаря

    my_dict_items = {'I-первый класс': (1001, 1200),
                     'II-второй класс': (501, 1000),
                     'III-третий класс': (301, 500),
                     'IV-четвёртый класс': (0, 300)
                     }

    my_dict = {'I-первый класс': (1001, 1200),
               'II-второй класс': (501, 1000),
               'III-третий класс': (301, 500),
               'IV-четвёртый класс': (0, 300)}

    user_answer = int(input("Введите значение: "))

    for key, value in my_dict.items():
        if isinstance(value, tuple):
            if value[0] <= user_answer <= value[1]:
                print(f"Указанный диаметр соответсвует нефтепроводу у которого: {key}")
                if key == random_key:
                    count_user += 10
                    print(
                        f"Это правильный ответ, указанный диаметр подходит классу из вопроса.\n Вам зачислено 10 баллов."
                        f"\n Количество ваших баллов {count_user}")
                else:
                    key != random_key
                    count_user = 0
                    print(f"Неправильный ответ , диаметр {user_answer} не подходит  классу нефтепровода из вопроса."
                          f"\nКоличество Ваших баллов не увеличилось.\nВсего у Вас {count_user} баллов")


            elif user_answer > 1200:
                print(f"Ответ неправильный. Вы набрали диаметр {user_answer} мм, который в данной проверке не рассматривается. "
                      f"\nКоличество Ваших баллов не увеличилось.\nВсего у Вас {count_user} баллов")
                break


        elif isinstance(value, str):
            if user_answer <= 300:
                print(f"Указанный диаметр соответсвует нефтепроводу у которого: {key}")
                if key == random_key:
                    count_user += 10
                    print(
                        f"Это правильный ответ, указанный диаметр подходит классу из вопроса.\n Вам зачислено 10 баллов."
                        f"\n Количество ваших баллов {count_user}")
                else:
                    key != random_key
                    count_user = 0
                    print(f"Неправильный ответ , диаметр {user_answer} не подходит  классу нефтепровода из вопроса."
                          f"\nКоличество Ваших баллов не увеличилось.\nВсего у Вас {count_user} баллов")


    print("Переходим к следующему вопросу:")

    iterator = iter([
        'Высота укладки упаковок покрытых электородов для ручной дуговой сварки в рядах:', #1 правильное количество рядов 5
        'Высота укладки упаковок порошковой проволоки:', #2 правильное количество рядов - 5
        'Температура хранения сварочных материалов в помещении\n(подсказка вариантов ответа:\n+10 градусов\n+15 градусов\n+20 градусов\n+25 градусов)', #3 правильная температура +15 градусов
        'Срок годности флюса для автоматической сварки кольцевых стыков трубопроводов \nдо повторной прокалки при хранении в сухих помещениях:\n(подсказка вариантов ответа: \n5 суток, \n10 суток, \n15 суток, \n20 или 25 суток)', #4 правильный срок годности 15 суток
        'Порошковую проволоку  перед выдачей необходимо прокаливать при температуре от +200 до +300 градусов:\n(подсказка вариантов ответа:\n0,5-1 час, \n1,5-2,5 часа, \n2,0-3,0 часа)', #5 правильный время от 1,5 до 2,5 часов
        'Режим прокалки электродов с основным видом покрытия до Э55А при температуре +300 град в часах: \n(подсказка:\n1 час,\n1,5 часа,\n3 часа,\n3,5 часа)',  #6 правильное время 1 час
        'Порошковая проволока, должна быть уложена отдельными мотками массой по 10 кг\n в жестяные банки весом не более:\n (подсказка:\n12 кг, \n15 кг, \n25 кг, \n35 кг, \n50 кг)',  #7 правильный вес 35 кг
        ])
    print(next(iterator))  #1 прав ответ 5 рядов
    user_answer_save_tools_1 = input()
    print(f"Вы выбрали количество рядов: {user_answer_save_tools_1}")
    if user_answer_save_tools_1 == '5':
        count_user += 10
        print(f"Правильный ответ, вам начислено 10 баллов, всего у Вас: {count_user} баллов. \nСледующий вопрос:")
    else:
        print("Неправильный ответ, баллы не начислены")

    print(next(iterator)) #2 прав ответ 5 рядов
    user_answer_save_tools_2 = input()
    print(f"Вы выбрали количество рядов: {user_answer_save_tools_2} штук")
    if user_answer_save_tools_2 == '5':
        count_user += 10
        print(f"Правильный ответ, вам начислено 10 баллов, всего у Вас: {count_user} баллов.")
    else:
        print("Неправильный ответ, баллы не начислены")

    print(next(iterator)) #3 прав температура +15
    user_answer_save_tools_3 = input().strip().upper()
    print(f"Вы выбрали значение температуры: {user_answer_save_tools_3}")
    if user_answer_save_tools_3 == '+15' or user_answer_save_tools_3 == '15' or user_answer_save_tools_3 == '15 градусов' or user_answer_save_tools_3 == '+15 градусов' or user_answer_save_tools_3 == '+15градусов' or user_answer_save_tools_3 == '15градусов':
        count_user += 10
        print(f"Правильный ответ, вам начислено 10 баллов, всего у Вас: {count_user} баллов.")
    else:
        print("Неправильный ответ, баллы не начислены")

    print(next(iterator)) #4 срок годности 15 суток
    user_answer_save_tools_4 = input().strip().upper()
    print(f"Вы выбрали срок хранения: {user_answer_save_tools_4}")
    if user_answer_save_tools_4 == '15' or user_answer_save_tools_4 == '15 суток' or user_answer_save_tools_4 == '15суток' or user_answer_save_tools_4 == '15СУТОК' or user_answer_save_tools_4 == '15 Суток':
        count_user += 10
        print(f"Правильный ответ, вам начислено 10 баллов, всего у Вас: {count_user} баллов.")
    else:
        print("Неправильный ответ, баллы не начислены")

    print(next(iterator))  # 5 прав ответ от 1,5 до 2,5 часов
    user_answer_save_tools_5 = input().strip().upper()
    print(f"Вы выбрали интервал времени: {user_answer_save_tools_5} ч.")
    if user_answer_save_tools_5 == '1,5-2,5часа' or user_answer_save_tools_5 == '1,5 - 2,5 ЧАСА' or user_answer_save_tools_5 == '1,5 - 2,5 Часа' or user_answer_save_tools_5 == '1,5 - 2,5 чАСА' or user_answer_save_tools_5 == '1,5-2,5':
        count_user += 10
        print(f"Правильный ответ, вам начислено 10 баллов, всего у Вас: {count_user} баллов.")
    else:
        print("Неправильный ответ, баллы не начислены")

    print(next(iterator))  # 6 прав время 1 час
    user_answer_save_tools_6 = input().strip().upper()
    print(f"Вы выбрали время: {user_answer_save_tools_6} ч.")
    if user_answer_save_tools_6 == '1' or user_answer_save_tools_6 == '1 час' or user_answer_save_tools_6 == '1час' or user_answer_save_tools_6 == '1ЧАС' or user_answer_save_tools_6 == '1 Час':
        count_user += 10
        print(f"Правильный ответ, вам начислено 10 баллов, всего у Вас: {count_user} баллов.")
    else:
        print("Неправильный ответ, баллы не начислены")

    print(next(iterator))  # 7 прав вес 35 кг
    user_answer_save_tools_7 = input().strip().upper()
    print(f"Вы указали вес: {user_answer_save_tools_7} кг")
    if user_answer_save_tools_7 == '35' or user_answer_save_tools_7 == '35кг' or user_answer_save_tools_7 == '35 КГ' or user_answer_save_tools_7 == '35кГ':
        count_user += 10
        print(f"Правильный ответ, вам начислено 10 баллов, всего у Вас: {count_user} баллов.")
    else:
        print("Неправильный ответ, баллы не начислены")

elif answer_user == 'нет':

   print("Программа завершена.\nДо новой встречи.")

elif answer_user.lower().strip(" ") == 'читать':

   print("Магистральные трубопроводы разделяются на 4-ре класса:"
         "\nI-первый класс: Диаметр трубопровода 1000-1200 мм включительно,"
         "\nII-второй класс: Диаметр трубопровода 500 - 1000 мм включительно, "
         "\nIII-третий класс: Диаметр трубопровода 300 - 500 мм включительно, "
         "\nIV-четвёртый класс: 300 мм и менее;"
         "\nВысота укладки упаковок покрытых электородов для ручной дуговой сварки в рядах: 5,"
         "\nВысота укладки упаковок порошковой проволоки: 5,"
         "\nТемпература хранения сварочных материалов в помещении правильная температура +15 градусов."
         "\nСрок годности флюса для автоматической сварки кольцевых стыков трубопроводов "
         "\nдо повторной прокалки при хранении в сухих помещениях: правильный срок годности 15 суток,"
         "\nПорошковую проволоку  перед выдачей необходимо прокаливать при температуре от +200 до +300 градусов: правильный время от 1,5 до 2,5 часов,"
         "\nРежим прокалки электродов с основным видом покрытия до Э55А при температуре +300 град в часах: правильное время 1 час,"
         "\nПорошковая проволока, должна быть уложена отдельными мотками массой по 10 кг в жестяные банки весом не более: правильный вес 35 кг")


elif answer_user.lower().strip(" ") == ' ':
   print("Программа завершена.\nДо новой встречи.")

else:
    answer_user.lower().strip(" ") == 'нет'
    print("Программа завершена.\nДо новой встречи.")
# Out:
# Вас приветствует программа проверки знаний специалиста сварочного производства.
# Готовы пройти проверку своих знаний?
#  Если готовы, наберите слово -
# Да,
# Если нет, наберите слово -
# Нет.
# Для ознакомления с материалами программы проверки
# наберите слово -
# Читать.
# Ваш ответ ... Да
# Введите Ваше Имя...
# Олег
# Олег, начинайте отвечать на вопросы, чтобы остановить проверку, наберите слово: стоп
# Условие: Нефтепровод -  II-второй класс,
# ВОПРОС: Напишите любой диаметр соответсвующий такому классу нефтепровода в миллиметрах:
# диаметры могут быть от 10 и до 1200 мм включительно
# Введите значение: 980
# Указанный диаметр соответсвует нефтепроводу у которого: II-второй класс
# Это правильный ответ, указанный диаметр подходит классу из вопроса.
#  Вам зачислено 10 баллов.
#  Количество ваших баллов 10
# Переходим к следующему вопросу:
# Высота укладки упаковок покрытых электородов для ручной дуговой сварки в рядах:
# 5
# Вы выбрали количество рядов: 5
# Правильный ответ, вам начислено 10 баллов, всего у Вас: 20 баллов.
# Следующий вопрос:
# Высота укладки упаковок порошковой проволоки:
# 5
# Вы выбрали количество рядов: 5 штук
# Правильный ответ, вам начислено 10 баллов, всего у Вас: 30 баллов.
# Температура хранения сварочных материалов в помещении
# (подсказка вариантов ответа:
# +10 градусов
# +15 градусов
# +20 градусов
# +25 градусов)
# 15
# Вы выбрали значение температуры: 15
# Правильный ответ, вам начислено 10 баллов, всего у Вас: 40 баллов.
# Срок годности флюса для автоматической сварки кольцевых стыков трубопроводов
# до повторной прокалки при хранении в сухих помещениях:
# (подсказка вариантов ответа:
# 5 суток,
# 10 суток,
# 15 суток,
# 20 или 25 суток)
# 15
# Вы выбрали срок хранения: 15
# Правильный ответ, вам начислено 10 баллов, всего у Вас: 50 баллов.
# Порошковую проволоку  перед выдачей необходимо прокаливать при температуре от +200 до +300 градусов:
# (подсказка вариантов ответа:
# 0,5-1 час,
# 1,5-2,5 часа,
# 2,0-3,0 часа)
# 1,5-2,5
# Вы выбрали интервал времени: 1,5-2,5 ч.
# Правильный ответ, вам начислено 10 баллов, всего у Вас: 60 баллов.
# Режим прокалки электродов с основным видом покрытия до Э55А при температуре +300 град в часах:
# (подсказка:
# 1 час,
# 1,5 часа,
# 3 часа,
# 3,5 часа)
# 1
# Вы выбрали время: 1 ч.
# Правильный ответ, вам начислено 10 баллов, всего у Вас: 70 баллов.
# Порошковая проволока, должна быть уложена отдельными мотками массой по 10 кг
#  в жестяные банки весом не более:
#  (подсказка:
# 12 кг,
# 15 кг,
# 25 кг,
# 35 кг,
# 50 кг)
# 35
# Вы указали вес: 35 кг
# Правильный ответ, вам начислено 10 баллов, всего у Вас: 80 баллов.
